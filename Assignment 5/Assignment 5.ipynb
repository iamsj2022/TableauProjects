# %% [markdown]
#     1.get acquainted with self joins (joining the same datasource to itself)
#     2.join the Superstore data to itself based on Order ID and where product sub categories are different
#     3create the visualisation above matching mine exactly
#     4.create a total sales calculation (sales of both product sub categories when bought together)sort the bars by highest total sales first
#     5.create a top n filter to show the top n product sub categories based on total sales

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
